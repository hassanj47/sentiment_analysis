# %% [markdown]
# ### Installs

# %%
# !pip install -q transformers
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 50.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 21.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 122.3 MB/s eta 0:00:00

# %%
# !pip install xformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 MB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 47.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 53.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 48.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 12.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 9.0 MB/s eta 0:00:00
# ...

# %%
# !pip install datasets
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 10.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 16.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 19.7 MB/s eta 0:00:00
# ...

# %%
# !pip install nlpaug
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.5/410.5 kB 8.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import wordnet
import random

# %%
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from transformers import pipeline

# %%
import torch
from sklearn.model_selection import train_test_split
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification, AdamW, AutoModelForSequenceClassification, AutoTokenizer
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import matplotlib.pyplot as plt

# %%
# Set random seeds for reproducibility
seed = 30
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %% [markdown]
# ### Input data

# %%
dataset = pd.read_csv('/content/drive/MyDrive/Projects/Case Studies/sentiment_analysis/amazonhelp_annotations.csv', index_col=0)

# %%
dataset.head()
# Out:
#         tweet_id  author_id  inbound                 created_at  \
# 63693    1732613   523365.0     True  2017-11-07 13:21:48+00:00
# 25613     575365   255384.0     True  2017-12-03 11:23:27+00:00
# 15057     348809   199027.0     True  2017-10-10 08:55:22+00:00
# 333003   2198802   643145.0     True  2017-11-10 02:30:12+00:00
# 329175   1912675   569728.0     True  2017-10-18 14:08:36+00:00
#
#                                                      text response_tweet_id  \
# 63693   @AmazonHelp @115830 yep, cs could not tell me ...           1732614
# 25613   @AmazonHelp Can you check if they’re being ful...            575367
# 15057   @AmazonHelp Five (5) days delayed and you're s...            348810
# 333003  @AmazonHelp I've done that, already. What good...           2198800
# 329175  @AmazonHelp hi I have used the vacuum bags I o...           1912674
#
#         in_response_to_tweet_id service_provider     label
# 63693                 1732612.0       amazonhelp  negative
# ...

# %%
dataset.shape
# Out:
# (300, 9)

# %%
to_predict = pd.read_parquet('/content/drive/MyDrive/Projects/Case Studies/sentiment_analysis/amazonhelp_preprocessed.gzip')

# %%
to_predict.head()
# Out:
#      tweet_id author_id  inbound                created_at  \
# 322       616    115820     True 2017-10-31 23:22:08+00:00
# 324       619    115820     True 2017-10-31 23:32:26+00:00
# 333       627    115827     True 2017-11-01 12:50:18+00:00
# 344       638    115834     True 2017-10-31 22:19:56+00:00
# 346       640    115834     True 2017-10-31 01:03:01+00:00
#
#                                                   text response_tweet_id  \
# 322  @AmazonHelp 3 different people have given 3 di...               618
# 324  @AmazonHelp I frankly don't have the patience ...              None
# 333  @AmazonHelp @115826 Yeah this is crazy we’re l...               629
# 344                 @AmazonHelp Hi ready for some help               637
# 346  @AmazonHelp Is the Echo Show no longer supported?               639
#
#      in_response_to_tweet_id service_provider
# 322                    615.0       amazonhelp
# 324                    618.0       amazonhelp
# ...

# %%
to_predict.shape
# Out:
# (93907, 8)

# %%
dataset =  dataset.sample(frac=1, random_state=seed) # resampling training data
#to_predict = to_predict.sample(n=1000, replace=False) # randomly sampling test data for predictions
to_predict = to_predict.sample(frac=1, random_state=seed)

# %%
dataset['text'] = dataset['text'].astype('string')
dataset['label'] = dataset['label'].astype('string')

# %%
to_predict['text'] = to_predict['text'].astype('string')

# %% [markdown]
# ### Finetuning distilbert

# %%
# Filtering inbound data 
dataset = dataset[['text','label']].copy()

# %%
# Define the mapping of string labels to corresponding integers
label_mapping = {
    'negative': 0,
    'neutral': 1,
    'positive': 2
}

# Map the string labels to integers
dataset['label'] = dataset['label'].map(label_mapping)
dataset.head()
# Out:
#                                                     text  label
# 23262  @AmazonHelp I got a package that I didn’t orde...      0
# 62244  @AmazonHelp Yeah I was thinking that too. Do y...      1
# 9877   @AmazonHelp This are orders no ..I know nxt ty...      0
# 19664  it's genuinely shaken me so much i was gonna c...      0
# 17861  @AmazonHelp @115830 364th day requesting any k...      1

# %%
# Define the dataset class
class SentimentDataset(Dataset):
    def __init__(self, dataframe, tokenizer, max_length):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_length = max_length
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        text = str(self.data.iloc[idx]['text'])
        label = self.data.iloc[idx]['label']
        
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt'
        )
        
        input_ids = encoding['input_ids'].squeeze()
        attention_mask = encoding['attention_mask'].squeeze()
        
        return {
            'input_ids': input_ids,
            'attention_mask': attention_mask,
            'label': label
        }

# Define train, validation, and test splitting
def split_data(dataframe, train_ratio=0.8, val_ratio=0.1, test_ratio=0.1):
    train_data, temp_data = train_test_split(dataframe, test_size=1 - train_ratio, random_state=42)
    val_data, test_data = train_test_split(temp_data, test_size=test_ratio/(test_ratio + val_ratio), random_state=42)
    
    return train_data, val_data, test_data

# Define the train function
def train(model, train_loader, optimizer, device):
    model.train()
    total_loss = 0.0
    total_correct = 0
    total_samples = 0
    
    for batch in train_loader:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)
        
        optimizer.zero_grad()
        
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_loss += loss.item()
        
        logits = outputs.logits
        preds = torch.argmax(logits, dim=1)
        
        total_correct += torch.sum(preds == labels).item()
        total_samples += labels.size(0)
        
        loss.backward()
        optimizer.step()
        
    avg_loss = total_loss / len(train_loader)
    accuracy = total_correct / total_samples
    
    return avg_loss, accuracy

# Define the evaluate function
def evaluate(model, data_loader, device):
    model.eval()
    total_loss = 0.0
    total_correct = 0
    
    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)
            
            outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
            loss = outputs.loss
            total_loss += loss.item()
            
            logits = outputs.logits
            preds = torch.argmax(logits, dim=1)
            total_correct += torch.sum(preds == labels).item()
    
    avg_loss = total_loss / len(data_loader)
    accuracy = total_correct / len(data_loader.dataset)
    
    return avg_loss, accuracy

# Create a dataset for prediction
class PredictionDataset(torch.utils.data.Dataset):
    def __init__(self, dataframe, tokenizer, max_length):
        self.data = dataframe
        self.tokenizer = tokenizer
        self.max_length = max_length

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        text = str(self.data.iloc[index]['text'])
        inputs = self.tokenizer.encode_plus(
            text,
            None,
            add_special_tokens=True,
            max_length=self.max_length,
            padding='max_length',
            truncation=True,
            return_token_type_ids=True,
            return_attention_mask=True,
        )

        input_ids = inputs['input_ids']
        attention_mask = inputs['attention_mask']

        return {
            'input_ids': torch.tensor(input_ids, dtype=torch.long),
            'attention_mask': torch.tensor(attention_mask, dtype=torch.long),
        }

def predict(model, data_loader, device):
    model.eval()
    predictions = []

    with torch.no_grad():
        for batch in data_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)

            outputs = model(input_ids, attention_mask=attention_mask)
            logits = outputs.logits
            preds = torch.argmax(logits, dim=1)

            predictions.extend(preds.cpu().numpy())

    # Convert predictions to labels
    label_map = {0: 'Negative', 1: 'Neutral', 2: 'Positive'}
    predicted_labels = [label_map[prediction] for prediction in predictions]

    return predicted_labels

# %%
# Set reasonable hyperparameters
max_length = 250
batch_size = 16
learning_rate = 2e-5
num_epochs = 10

# %%
# Split the data into train, validation, and test sets
train_data, val_data, test_data = split_data(dataset)

# %%
train_data.shape
# Out:
# (240, 2)

# %%
import nlpaug.augmenter.word as naw

# Initialize the augmentation augmenter
augmenter = naw.ContextualWordEmbsAug(
    model_path='bert-base-uncased',
    action='substitute',
    device='cuda' if torch.cuda.is_available() else 'cpu'
)

# Function for data augmentation
def augment_data(text, label, num_augmentations=3):
    augmented_texts = []
    augmented_labels = []

    for _ in range(num_augmentations):
        augmented_text = augmenter.augment(text)
        augmented_texts.append(augmented_text)
        augmented_labels.append(label)

    return augmented_texts, augmented_labels

# Apply data augmentation to the training data
num_augmentations = 6  # Number of augmented samples to generate per original sample

augmented_texts = []
augmented_labels = []

for text, label in zip(train_data['text'], train_data['label']):
    texts, labels = augment_data(text, label, num_augmentations)
    augmented_texts.extend(texts)
    augmented_labels.extend(labels)

augmented_train_data = pd.DataFrame({'text': augmented_texts, 'label': augmented_labels})

# Concatenate the augmented dataset with the original training data
augmented_train_data = pd.concat([train_data, augmented_train_data], ignore_index=True)

# %%
# augmented_train_data.shape

# %%
# Initialize the tokenizer and model
# tokenizer = DistilBertTokenizer.from_pretrained('distilbert-base-uncased')
# model = DistilBertForSequenceClassification.from_pretrained('distilbert-base-uncased', num_labels=3)
MODEL = "cardiffnlp/twitter-roberta-base-sentiment"

model = AutoModelForSequenceClassification.from_pretrained(MODEL)
tokenizer = AutoTokenizer.from_pretrained(MODEL)

# %%
# Create the dataset and data loaders
train_dataset = SentimentDataset(train_data, tokenizer, max_length)
val_dataset = SentimentDataset(val_data, tokenizer, max_length)
test_dataset = SentimentDataset(test_data, tokenizer, max_length)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
# Set up the device for training
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model.to(device)

# Set the loss function and optimizer
criterion = torch.nn.CrossEntropyLoss()
optimizer = AdamW(model.parameters(), lr=learning_rate, weight_decay=0.01)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:407: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(

# %%
# Training loop
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

for epoch in range(num_epochs):
    train_loss, train_accuracy = train(model, train_loader, optimizer, device)
    val_loss, val_accuracy = evaluate(model, val_loader, device)
    
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_accuracy)
    val_accuracies.append(val_accuracy)
    
    print(f'Epoch {epoch+1}/{num_epochs}:')
    print(f'Train Loss: {train_loss:.4f} | Train Accuracy: {train_accuracy:.4f}')
    print(f'Validation Loss: {val_loss:.4f} | Validation Accuracy: {val_accuracy:.4f}\n')
# Out:
# Epoch 1/10:
# Train Loss: 0.3978 | Train Accuracy: 0.8208
# Validation Loss: 0.4842 | Validation Accuracy: 0.8667
#
# Epoch 2/10:
# Train Loss: 0.2188 | Train Accuracy: 0.9208
# Validation Loss: 0.8854 | Validation Accuracy: 0.7667
#
# Epoch 3/10:
# Train Loss: 0.1796 | Train Accuracy: 0.9333
# Validation Loss: 0.3371 | Validation Accuracy: 0.9000
#
# Epoch 4/10:
# Train Loss: 0.0657 | Train Accuracy: 0.9792
# Validation Loss: 0.6126 | Validation Accuracy: 0.8000
#
# Epoch 5/10:
# Train Loss: 0.0264 | Train Accuracy: 0.9917
# Validation Loss: 0.3311 | Validation Accuracy: 0.8667
#
# Epoch 6/10:
# Train Loss: 0.0129 | Train Accuracy: 1.0000
# Validation Loss: 0.3811 | Validation Accuracy: 0.8667
#
# Epoch 7/10:
# Train Loss: 0.0118 | Train Accuracy: 1.0000
# Validation Loss: 0.4490 | Validation Accuracy: 0.9000
#
# Epoch 8/10:
# Train Loss: 0.0092 | Train Accuracy: 0.9958
# Validation Loss: 0.5468 | Validation Accuracy: 0.8333
#
# Epoch 9/10:
# ...

# %%
# Plot training and validation losses
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_losses, label='Train Loss')
plt.plot(range(1, num_epochs+1), val_losses, label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# %%
# Plot training and validation accuracies
plt.figure(figsize=(10, 5))
plt.plot(range(1, num_epochs+1), train_accuracies, label='Train Accuracy')
plt.plot(range(1, num_epochs+1), val_accuracies, label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracies')
plt.legend()
plt.show()

# %%
results = pd.DataFrame({'train_loss':train_losses,'val_loss':val_losses,'train_acc':train_accuracies,'val_acc':val_accuracies})
results
# Out:
#    train_loss  val_loss  train_acc   val_acc
# 0    0.397832  0.484213   0.820833  0.866667
# 1    0.218767  0.885393   0.920833  0.766667
# 2    0.179619  0.337100   0.933333  0.900000
# 3    0.065655  0.612610   0.979167  0.800000
# 4    0.026402  0.331064   0.991667  0.866667
# 5    0.012949  0.381095   1.000000  0.866667
# 6    0.011834  0.449022   1.000000  0.900000
# 7    0.009178  0.546781   0.995833  0.833333
# 8    0.005256  0.642590   1.000000  0.833333
# 9    0.008708  0.459832   0.995833  0.900000

# %%
# Evaluate on the test set
test_loss, test_accuracy = evaluate(model, test_loader, device)
print(f'Test Loss: {test_loss:.4f}')
print(f'Test Accuracy: {test_accuracy:.4f}\n')
# Out:
# Test Loss: 0.0839
# Test Accuracy: 0.9667

# %%
# Predict on the unlabeled dataset
to_predict_dataset = PredictionDataset(to_predict, tokenizer, max_length)
to_predict_loader = DataLoader(to_predict_dataset, batch_size=batch_size, shuffle=False)
to_predict_predictions = predict(model, to_predict_loader, device)
to_predict['predicted_label'] = to_predict_predictions
to_predict.to_parquet('/content/drive/MyDrive/Projects/Case Studies/sentiment_analysis/amazonhelp_proc_preds.gzip')
to_predict.head()
# Out:
#          tweet_id author_id  inbound                created_at  \
# 2130234   2291363    665502     True 2017-11-13 04:53:59+00:00
# 995541    1103600    380430     True 2017-10-24 00:01:19+00:00
# 1136452   1255684    159105     True 2017-10-26 12:00:44+00:00
# 2042085   2200742    643625     True 2017-11-26 14:21:55+00:00
# 64157       80723    133905     True 2017-12-01 13:16:56+00:00
#
#                                                       text  \
# 2130234  @AmazonHelp I don't accept ur aoology, i u wan...
# 995541   @AmazonHelp Only chat feature available. Been ...
# 1136452  @AmazonHelp Forget it your's is useless custom...
# 2042085  @AmazonHelp Don’t know was just told this is w...
# 64157    @AmazonHelp Thank you amazon. Received my pack...
#
#                response_tweet_id  in_response_to_tweet_id service_provider  \
# 2130234  2291364,2291365,2291366                2291362.0       amazonhelp
# 995541                      None                1103597.0       amazonhelp
# ...

# %%
to_predict.shape
# Out:
# (93907, 9)

# %%
to_predict_counts = to_predict.groupby('predicted_label').size()

# %%
sns.barplot(x=to_predict_counts.index, y=to_predict_counts.values)

plt.title('Distribution of sentiments')
plt.xlabel('sentiment')
plt.ylabel('count')
plt.xticks(rotation=45)

plt.show()

# %%
# Save the model
model_save_path = "/content/drive/MyDrive/Projects/Case Studies/sentiment_analysis/roberta-sentiment"
model.save_pretrained(model_save_path)

# %%
print('all done!')
# Out:
# all done!
